# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import neighbors
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv')

# %%
data.head()

# %%
data.isnull().sum()

# %%
plt.hist(data['age'], edgecolor = 'black',bins =20 )
plt.xlabel('Age')
plt.ylabel('Number')
plt.title('AGE')
plt.xlim()
plt.show()

# %%
fig,ax = plt.subplots(ncols=1, nrows=1, constrained_layout=True)
fig,bx = plt.subplots(ncols=1, nrows=1, constrained_layout=True)

male_pos = ((data['sex'] == 1) & (data['target'] == 1)).sum()
male_neg = ((data['sex'] == 1) & (data['target'] == 0)).sum()
female_pos = ((data['sex'] == 0) & (data['target'] == 1) ).sum()
female_neg = ((data['sex'] == 0) & (data['target'] == 0) ).sum()
tot_pos = male_pos + female_pos
tot_neg = male_neg + female_neg
ax.bar([0,1],[tot_neg,tot_pos])
ax.set_xticks([0,1])

d = [[female_neg,female_pos],[male_neg,male_pos]]
X = np.arange(2)
bx.set_xticks([0,1])
bx.bar(X + 0.00, d[0], color = 'b', width = 0.25)
bx.bar(X + 0.25, d[1], color = 'g', width = 0.25)
bx.legend(['Female','Male'])


plt.show()

# %%
grp = data.groupby('cp')['cp'].count()
fig = plt.figure()
a = fig.add_axes([0,0,1,1])
a.bar([0,1,2,3],grp)
a.set_xticks([0,1,2,3])
plt.xlabel('Type')
plt.ylabel('Frequency')
plt.title('Chest pain type')
plt.show()

# %%
plt.hist(data['trestbps'], edgecolor = 'black')
plt.title('BP on admission')
plt.xlabel('BP')
plt.ylabel('frequency')
plt.show()

# %%
plt.hist(data['chol'], edgecolor = 'black' ,bins = 20)
plt.title('Cholestoral')
plt.xlabel('Cholestoral(mg/dl)')
plt.ylabel('frequency')
plt.show()

# %%
fbs = data.groupby('fbs')['fbs'].count()
print(fbs)

# %%
restecg = data.groupby('restecg')['restecg'].count()
restecg

# %%
exang = data.groupby('exang')['exang'].count()
exang

# %%
slope = data.groupby('slope')['slope'].count()
slope

# %%
ca = data.groupby('ca')['ca'].count()
ca

# %%
thal = data.groupby('thal')['thal'].count()
thal

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]
# std = preprocessing.StandardScaler()
# X = std.fit_transform(X)

# %%
temp = X.copy()
col = ['age','trestbps','chol','thalach','oldpeak']
features = temp[col]
scaler = preprocessing.StandardScaler().fit(features.values)
features = scaler.transform(features.values)
X[col] = features

# %%
# temp2 = X.copy()
# col_2 = ['sex','cp','fbs','restecg','exang','slope','ca','thal']
# features_2 = temp2[col_2]
# enc = OneHotEncoder(handle_unknown='ignore')
# trial = pd.DataFrame(enc.fit_transform(features_2).toarray())
# X = X.join(trial)

# %%
X

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.25, random_state=42)

# %%
enc = LogisticRegression(max_iter = 10000)
enc.fit(X_train,y_train)

# %%
y_pred = enc.predict(X_test)
metrics.accuracy_score(y_test,y_pred)

# %%
svc = SVC(kernel='linear')
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
metrics.accuracy_score(y_test,y_pred)

# %%
gnb = GaussianNB()
gnb.fit(X_train,y_train)
y_pred = gnb.predict(X_test)
metrics.accuracy_score(y_test,y_pred)

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
metrics.accuracy_score(y_test,y_pred)

# %%
rnf = RandomForestClassifier(max_depth=8, random_state=0)
rnf.fit(X, y)
y_pred = rnf.predict(X_test)
metrics.accuracy_score(y_test,y_pred)
